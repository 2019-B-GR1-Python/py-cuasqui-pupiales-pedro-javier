# %%
import numpy as np

from scipy import ndimage

# %%
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(mapache)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
mapachet= mapache[::-1]
plt.imshow(mapachet)

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
#se muestra la imagen en el canal RED
res= mapache[:,:,0]
plt.imshow(res)

# %%
#se muestra la imagen en el canal GREEN
plt.imshow(mapache[:,:,1])

# %%
#se muestra la imagen en el canal BLUE
 
plt.imshow(mapache[:,:,2])

# %%
mapache1=np.copy(mapache) # creo una copia de la imagen para preservar la original
#Se enceran los valores del canal verde y azul del mapache
mapache1[:,:,1]=0
mapache1[:,:,2]=0
plt.imshow(mapache1)

# %%
#Se guarda la imagen
io.imsave("mapache1.png",mapache1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-d0463ade0673> in <module>
#       1 #Se guarda la imagen
# ----> 2 io.imsave("mapache1.png",mapache1)
#
# NameError: name 'io' is not defined

# %%
arr1, arr2 =np.vsplit(mapache,2)
plt.imshow(arr1)

# %%
plt.imshow(arr2)

# %%
import cv2
mapache1= mapache
res = cv2.resize(mapache1, dsize=(54, 140), interpolation=cv2.INTER_CUBIC)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-64-92964043095a> in <module>
# ----> 1 import cv2
#       2 mapache1= mapache
#       3 res = cv2.resize(mapache1, dsize=(54, 140), interpolation=cv2.INTER_CUBIC)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
img1= misc.imresize(mapache, 150, interp='bilinear', mode=None)
plt.imshow(img1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   """Entry point for launching an IPython kernel.
